# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2020-10-23 18:18:54,462: Credentials are already in use. The existing account in the session will be replaced.

# %%
qr = QuantumRegister(2, 'my_Q')
cr = ClassicalRegister(2, 'my_C')
qc = QuantumCircuit(qr,cr)
qc.draw()

# %%
#Concatenating 2 Quantum circuits
qr1 = QuantumRegister(2, name='qr1')
cr1 = ClassicalRegister(2, name='cr1')
qc1 = QuantumCircuit(qr1,cr1)
qc1.draw()

# %%
qr2 = QuantumRegister(2, name='qr2')
cr2 = ClassicalRegister(2, name='cr2')
qc2 = QuantumCircuit(qr2,cr2)
qc2.draw()

# %%
qc_combined = qc1 + qc2
qc_combined.draw()

# %%
from qiskit.circuit.random import random_circuit
qc = random_circuit(3, 9, measure=True)
qc.draw()

# %%
qc1= random_circuit(2,2)
qc2= random_circuit(2,4)
qc = qc1 + qc2
qc.draw()

# %%
qc1.draw()

# %%
qc2.draw()

# %%
def print_circuit_props(qc):
    width = qc.width()
    depth = qc.depth()
    num_operators = qc.count_ops()
    circuit_size = qc.size()
    print('Width = ',width)
    print('Depth = ', depth)
    print('Circuit size = ',circuit_size)
    print('Number of operators = ', num_operators)

# %%
print_circuit_props(qc)
# Out:
# Width =  2
# Depth =  6
# Circuit size =  10
# Number of operators =  OrderedDict([('ry', 2), ('tdg', 2), ('rx', 2), ('u3', 1), ('u2', 1), ('cu3', 1), ('rzz', 1)])

# %%
print_circuit_props(qc1)
# Out:
# Width =  2
# Depth =  2
# Circuit size =  4
# Number of operators =  OrderedDict([('ry', 1), ('tdg', 1), ('rx', 1), ('u3', 1)])

# %%
print_circuit_props(qc2)
# Out:
# Width =  2
# Depth =  4
# Circuit size =  6
# Number of operators =  OrderedDict([('u2', 1), ('ry', 1), ('tdg', 1), ('rx', 1), ('cu3', 1), ('rzz', 1)])

# %%
qc.measure_all()
qc.draw()

# %%
print_circuit_props(qc)
# Out:
# Width =  4
# Depth =  7
# Circuit size =  12
# Number of operators =  OrderedDict([('ry', 2), ('tdg', 2), ('rx', 2), ('measure', 2), ('u3', 1), ('u2', 1), ('cu3', 1), ('rzz', 1), ('barrier', 1)])

# %%
qc = QuantumCircuit(3)
qc.ccx(0,1,2)
qc.draw()

# %%
print_circuit_props(qc)
# Out:
# Width =  3
# Depth =  1
# Circuit size =  1
# Number of operators =  OrderedDict([('ccx', 1)])

# %%
print_circuit_props(qc.decompose())
# Out:
# Width =  3
# Depth =  11
# Circuit size =  15
# Number of operators =  OrderedDict([('cx', 6), ('t', 4), ('tdg', 3), ('h', 2)])
