# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
provider = IBMQ.load_account()
# Out:
# /opt/conda/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
qc = QuantumCircuit(4)
qc.h(0)
qc.cx(0,1)
qc.barrier()
qc.cx(0,2)
qc.cx(0,3)
qc.barrier()
qc.cz(3,0)
qc.h(0)
qc.measure_all()
qc.draw()

# %%
qc.draw('latex')
# Out:
# <PIL.Image.Image image mode=RGB size=1051x266 at 0x7F65509C6D50>

# %%
# Define style to render the circuit and components
style = {'background': 'lightblue','gatefacecolor':'white', 'gatetextcolor': 'black', 'fontsize': 9}
qc.draw(style=style)
# Out:
# /opt/conda/lib/python3.7/site-packages/qiskit/visualization/matplotlib.py:167: DeprecationWarning: style option/s (background) is/are not supported
#   self._style.set_style(style)

# %%
# Import circuit to DAG converter
from qiskit.converters import circuit_to_dag
# Import Dag drawer
from qiskit.tools.visualization import dag_drawer
dag = circuit_to_dag(qc)
dag_drawer(dag)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=670x973 at 0x7F66151C1190>
